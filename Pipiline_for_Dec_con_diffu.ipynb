# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
requirements = "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project/requirements.txt"
# !pip install -r "{requirements}"

# Sanity check
import torch
from diffusers import StableDiffusionInpaintPipeline

print(torch.cuda.is_available())
# Out:
# ...
#   Using cached xformers-0.0.33.post2-cp39-abi3-manylinux_2_28_x86_64.whl.metadata (1.2 kB)
# ...
#   Using cached pyiqa-0.1.14.1-py3-none-any.whl.metadata (18 kB)
# ERROR: Could not find a version that satisfies the requirement sklearn-image (from versions: none)
# ERROR: No matching distribution found for sklearn-image
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# True

# %%
# !ls "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project"
# %cd "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project"
# Out:
#  brisque_colab.py       mask_test	   Pipiline_for_Dec_con_diffu.ipynb
#  Converter.py	        ML_mask_gen.py	   process_file.py
#  corrupt_data.py        nerf_synthetic	   __pycache__
#  detect_corruption.py   nsenv		   README.md
#  Detection_script      'Original Images'   requirements.txt
#  diffusion_script.py    others		   test_image
#  inpainting_ready       output		   user_guide.md
#  mask2.py	        output_processed   weights
#  Mask_generation        output_train
# /content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D project

# %%
# !nvidia-smi
# !ls "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project/output_processed/lego"
# !pip install basicsr
# !pip install facexlib
# !pip install gfpgan
# !pip install -r https://raw.githubusercontent.com/xinntao/Real-ESRGAN/master/requirements.txt
# !python setup.py develop
# !pip install realesrgan
# !pip install rembg
# !pip install onnxruntime-gpu
# Out:
# Thu Jan  1 13:00:55 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 550.54.15              Driver Version: 550.54.15      CUDA Version: 12.4     |
# |-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA A100-SXM4-40GB          Off |   00000000:00:04.0 Off |                    0 |
# | N/A   31C    P0             43W /  400W |       5MiB /  40960MiB |      0%      Default |
# |                                         |                        |             Disabled |
# ...

# %%
# !pip install rembg
# !pip install onnxruntime-gpu
# Run this in a notebook cell to fix the library permanently
# !sed -i 's/from torchvision.transforms.functional_tensor import rgb_to_grayscale/from torchvision.transforms.functional import rgb_to_grayscale/' /usr/local/lib/python3.12/dist-packages/basicsr/data/degradations.py
input_directory = "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project/output_processed/mic"
output_directory = "/content/drive/MyDrive/pythonprojects_2/final_year_project/gaussian-splatting/3D project/output_processed/mic"

# !python diffusion_script.py --input_dir "{input_directory}" --out_dir "{output_directory}"
# Out:
# ...
# 2026-01-01 14:21:06.381531: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767277266.403148   59943 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767277266.409674   59943 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767277266.426699   59943 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
