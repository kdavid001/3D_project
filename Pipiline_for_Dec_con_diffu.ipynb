# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
requirements = "/content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D_project/requirements.txt"
# !pip install -r "{requirements}"

# Sanity check
import torch
from diffusers import StableDiffusionInpaintPipeline

print(torch.cuda.is_available())
# Out:
# ...
# INFO: pip is looking at multiple versions of xformers to determine which version is compatible with other requirements. This could take a while.
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 122.9/122.9 MB 7.0 MB/s eta 0:00:00
# ...
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v1.0.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# True

# %%
# !ls "/content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D_project"
# %cd "/content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D_project"
# Out:
#  Converter.py
#  corrupt_data.py
#  detect_corruption.py
#  diffusion_script.py
# 'gaussian splatting .glb'
#  nsenv
# 'Original Images'
#  output
#  output_train
#  Pipiline_for_Dec_con_diffu.ipynb
#  process_file.py
#  README.md
#  requirements.txt
# 'research files'
# 'some liinks.txt'
#  tandt_db
#  test_image
# 'Tutorial Video.mp4'
#  user_guide.md
#  YTDown.com_YouTube_TUM-AI-Lecture-Series-The-3D-Gaussian-Sp_Media_DjOqkVIlEGY_001_720p.mp4
# /content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D_project

# %%
input_directory = "/content/drive/MyDrive/pythonprojects_2/3D_project/gaussian-splatting/3D_project/output_train/train"
# !python  diffusion_script.py --DATASET_DIR "{input_directory}"
# Out:
# 2025-12-20 12:07:33.088274: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1766232453.109291    4376 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1766232453.115267    4376 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1766232453.130672    4376 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...
